# %% [markdown]
# #1장 시작하기 전에

# %%
#import 컨벤션
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
import statsmodels as sm

# %% [markdown]
# # 2장 IPython, 주피터 노트북

# %% [markdown]
# ##파이썬 인터프리터

# %% [markdown]
# ##IPython 기초

# %% [markdown]
# ###IPython 셸 실행하기

# %%
a = 5
a
# Out:
# 5

# %%
#평균 0, 표준 편차1의 표준 정규 분포
normal_distribution = {i : np.random.randn() for i in range(7)}
normal_distribution
# Out:
# {0: 1.4131346574355108,
#  1: 0.41694790787603647,
#  2: 1.0929629553021887,
#  3: 0.9949039865573622,
#  4: 0.9865755481259681,
#  5: 1.36698969433584,
#  6: 0.5161510722556323}

# %%
from numpy.random import randn
rand_data = {i : randn() for i in range(7)}
rand_data
# Out:
# {0: -0.8825446244815505,
#  1: 0.3449926034201585,
#  2: 0.9748671816664943,
#  3: -0.6220705966019554,
#  4: 0.48888804161781957,
#  5: 1.367917767290753,
#  6: 2.2615264932633785}

# %% [markdown]
# ###주피터 노트북

# %%
print('hello World!')
# Out:
# hello World!

# %% [markdown]
# ###탭 자동완성

# %%
an_apple = 27
an_example = 42
b = [1,2,3]

# %%
import datetime

# %% [markdown]
# ###자기관리

# %% [markdown]
# 변수이름 앞이나 뒤에 ?기호 : 객체에 대한 일반 정보
#
# ?? : 함수의 소스 코드 보여줌
#
# *문자 기호와 함께 : 문자와 일치하는 모든 이름

# %% [markdown]
# ###%run명령어

# %% [markdown]
# ###클립보드에 있는 코드 실행하기

# %% [markdown]
# ###키보드 단축키

# %% [markdown]
# ###매직 명령어

# %% [markdown]
# ###matplotlib 통합

# %% [markdown]
# ##파이썬 기초

# %% [markdown]
# ###시맨틱

# %% [markdown]
# ####들여쓰기

# %%
for x in array : 
  if x < pivot:
    less.append(x)
  else:
    greater.append(x)

a=5;b=6;c=7

# %% [markdown]
# ####모든 것은 객체

# %% [markdown]
# ####주석

# %%
results = []
for line in file_handle:
    #아래 코느는 실행되지 않는다.
    #if len(line) == 0:
    #     continue
    results.append(line.replace('foo', 'bar'))

print("Reached this line")

# %% [markdown]
# ####함수와 객체 메서드 호출

# %%
result = f(x,y,z)
g()

# %%
obj.some_method(x,y,z)

# %%
result = f(a,b,c,d=5, e='foo')

# %% [markdown]
# ####변수와 인자 전달

# %%
a = [1,2,3]
b = a

# %%
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
#apppend 함수 정의
def append_element(some_list, element):
  some_list.append(element)

# %%
append_data = [1,2,3]
append_element(append_data, 4)
append_data
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ####동적 참조와 강한 타입

# %%
a = 5
type(a)

# %%
a = 'foo'
type(a)

# %%
a = 4.5
b = 2
print('a is {0}, b is {1}'.format(type(a), type(b)))
# Out:
# a is <class 'float'>, b is <class 'int'>

# %%
a/b
# Out:
# 2.25

# %%
a = 5
isinstance(a, int)
# Out:
# True

# %%
a = 5; b = 4.5
isinstance(a, (int, float))
# Out:
# True

# %%
isinstance(b, (int, float))
# Out:
# True

# %% [markdown]
# ####속성과 메서드

# %%
a = 'foo'
getattr(a, 'split')
# Out:
# <function str.split(sep=None, maxsplit=-1)>

# %% [markdown]
# ####덕 타이핑

# %% [markdown]
# ####모듈 임포트

# %%
a = [1,2,3]
b = a

# %% [markdown]
# ####이항 연산자와 비교문

# %%
a = [1,2,3]
b = a

# %% [markdown]
# ####뮤터블, 이뮤터블 객체

# %%
a = [1,2,3]
b = a

# %% [markdown]
# ###스칼라형

# %% [markdown]
# ####숫자 자료형

# %%
ival = 17239871
ival ** 6
# Out:
# 26254519291092456596965462913230729701102721

# %%
fval = 7.243
fval2 = 6.78e-5
# Out:
# 6.78e-05

# %%
3 / 2
# Out:
# 1.5

# %%
3 // 2
# Out:
# 1

# %% [markdown]
# ####문자열
